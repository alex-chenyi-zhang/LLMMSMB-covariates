# %%
using Plots, DelimitedFiles
using Distributions, StatsBase, LinearAlgebra

# %%
region_y = "log_chr2_1000_66000_100k_oe_gf2" 

data_dir = "../data/preliminary_results/$(region_y)/"
# Out:
# "../data/preliminary_results/log_chr2_1000_66000_100k_oe_gf2/"

# %%
io = open("$(data_dir)cor.txt","r")
cor_mat = readdlm(io, Float64)
close(io)

io = open("$(data_dir)cor_2.txt","r")
cor_mat_2 = readdlm(io, Float64)
close(io)

io = open("$(data_dir)cor_3.txt","r")
cor_mat_3 = readdlm(io, Float64)
close(io)

io = open("$(data_dir)cor_4.txt","r")
cor_mat_4 = readdlm(io, Float64)
close(io)

# %%
io = open("$(data_dir)cor_cor.txt","r")
cor_cor = readdlm(io, Float64)
close(io)

io = open("$(data_dir)cor_cor_2.txt","r")
cor_cor_2 = readdlm(io, Float64)
close(io)

io = open("$(data_dir)cor_cor_3.txt","r")
cor_cor_3 = readdlm(io, Float64)
close(io)

io = open("$(data_dir)cor_cor_4.txt","r")
cor_cor_4 = readdlm(io, Float64)
close(io)

# %%
io = open("$(data_dir)cor_50dist.txt","r")
cor_r = readdlm(io, Float64)
close(io)

io = open("$(data_dir)cor_50dist_2.txt","r")
cor_r_2 = readdlm(io, Float64)
close(io)

io = open("$(data_dir)cor_50dist_3.txt","r")
cor_r_3 = readdlm(io, Float64)
close(io)

io = open("$(data_dir)cor_50dist_4.txt","r")
cor_r_4 = readdlm(io, Float64)
close(io)

# %%
io = open("$(data_dir)cor_pred.txt","r")
cor_mat_pred = readdlm(io, Float64)
close(io)

io = open("$(data_dir)cor_pred_2.txt","r")
cor_mat_pred_2 = readdlm(io, Float64)
close(io)

io = open("$(data_dir)cor_pred_3.txt","r")
cor_mat_pred_3 = readdlm(io, Float64)
close(io)

io = open("$(data_dir)cor_pred_4.txt","r")
cor_mat_pred_4 = readdlm(io, Float64)
close(io)

# %%
io = open("$(data_dir)cor_cor_pred.txt","r")
cor_cor_pred = readdlm(io, Float64)
close(io)

io = open("$(data_dir)cor_cor_pred_2.txt","r")
cor_cor_pred_2 = readdlm(io, Float64)
close(io)

io = open("$(data_dir)cor_cor_pred_3.txt","r")
cor_cor_pred_3 = readdlm(io, Float64)
close(io)

io = open("$(data_dir)cor_cor_pred_4.txt","r")
cor_cor_pred_4 = readdlm(io, Float64)
close(io)

# %%
io = open("$(data_dir)cor_50dist_pred.txt","r")
cor_r_pred = readdlm(io, Float64)
close(io)

io = open("$(data_dir)cor_50dist_pred_2.txt","r")
cor_r_pred_2 = readdlm(io, Float64)
close(io)

io = open("$(data_dir)cor_50dist_pred_3.txt","r")
cor_r_pred_3 = readdlm(io, Float64)
close(io)

io = open("$(data_dir)cor_50dist_pred_4.txt","r")
cor_r_pred_4 = readdlm(io, Float64)
close(io)

# %%
ks = [6,6,6,6,6,6,6,6, 8,8,8,8,8,8,8,8, 10,10,10,10,10,10,10,10, 12,12,12,12,12,12,12,12];

# %% [markdown]
# Maps generates from MAP $\pmb{\theta}_i$
# ====

# %% [markdown]
# Correlations of raw matrices
# ----

# %%
scatter(ks, vec(cor_mat'), alpha=0.9, size = (700,400))
scatter!(ks .+ 0.1, vec(cor_mat_2'), alpha=0.9)
scatter!(ks .+ 0.2, vec(cor_mat_3'), alpha=0.9)
scatter!(ks .+ 0.3, vec(cor_mat_4'), alpha=0.9)

# %% [markdown]
# Excluding first 50 main diagonals
# ---

# %%
scatter(ks, vec(cor_r'), alpha=0.9, size = (700,400))
scatter!(ks .+ 0.1, vec(cor_r_2'), alpha=0.9)
scatter!(ks .+ 0.2, vec(cor_r_3'), alpha=0.9)
scatter!(ks .+ 0.3, vec(cor_r_4'), alpha=0.9)

# %% [markdown]
# Correlations between auto-correlation matrices
# -----

# %%
scatter(ks , vec(cor_cor'), alpha=0.9, size = (700,400))
scatter!(ks .+ 0.1, vec(cor_cor_2'), alpha=0.9)
scatter!(ks .+ 0.2,  vec(cor_cor_3'), alpha=0.9)
scatter!(ks .+ 0.3, vec(cor_cor_4'), alpha=0.9)

# %% [markdown]
# Maps generated from covariates $\pmb{\mu}_i = \pmb{\Gamma}\pmb{X}_i$
# =====

# %% [markdown]
# Correlations of raw matrices
# ----

# %%
scatter(ks, vec(cor_mat_pred'), alpha=0.9, size = (700,400))
scatter!(ks .+ 0.2, vec(cor_mat_pred_2'), alpha=0.9)
scatter!(ks .+ 0.4, vec(cor_mat_pred_3'), alpha=0.9)
scatter!(ks .+ 0.6, vec(cor_mat_pred_4'), alpha=0.9)

# %% [markdown]
# Excluding first 50 main diagonals
# ---

# %%
scatter(ks, vec(cor_r_pred'), alpha=0.9, size = (700,400))
scatter!(ks .+ 0.2, vec(cor_r_pred_2'), alpha=0.9)
scatter!(ks .+ 0.4, vec(cor_r_pred_3'), alpha=0.9)
scatter!(ks .+ 0.6, vec(cor_r_pred_4'), alpha=0.9)

# %% [markdown]
# Correlations between auto-correlation matrices
# -----

# %%
scatter(ks , vec(cor_cor_pred'), alpha=0.9, size = (700,400))
scatter!(ks .+ 0.2, vec(cor_cor_pred_2'), alpha=0.9)
scatter!(ks .+ 0.4,  vec(cor_cor_pred_3'), alpha=0.9)
scatter!(ks .+ 0.6, vec(cor_cor_pred_4'), alpha=0.9)
